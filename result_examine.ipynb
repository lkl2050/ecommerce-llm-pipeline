# %%
import requests
import json
import pandas as pd

# API base URL
BASE_URL = "http://127.0.0.1:8080"


def start_scraping(max_products=10):
    """Start scraping new products"""
    response = requests.post(f"{BASE_URL}/refresh?max_products={max_products}")
    return response.json()

def check_health():
    """Check API health"""
    response = requests.get(f"{BASE_URL}/health")
    return response.json()

# %%
check_health()
# Out:
# {'status': 'healthy',
#  'cached_products': 24,
#  'scraping_active': False,
#  'last_scraped': '2025-05-31T17:25:25.882339',
#  'storage_file': 'products_database.json',
#  'file_exists': True,
#  'file_size_kb': 45.14}

# %%
start_scraping(max_products=10)
# Out:
# {'message': 'Started scraping 10 products',
#  'status': 'processing',
#  'current_total': 24}

# %%
def load_products_from_json():
    """Load products directly from JSON file"""
    try:
        with open('products_database.json', 'r') as f:
            return json.load(f)
    except FileNotFoundError:
        print("JSON file not found")
        return None


data = load_products_from_json()
products = data['products'] if data else []

if products:
    df = pd.DataFrame(products)

    # Basic info
    print("=== DATASET OVERVIEW ===")
    print(f"Total products: {len(df)}")
    print(f"Columns: {list(df.columns)}")
    print(f"\nData types:")
    print(df.dtypes)

    # Show first few products
    display(df[['title', 'price', 'rating']].head(50))
# Out:
# === DATASET OVERVIEW ===
# Total products: 15
# Columns: ['title', 'price', 'description', 'url', 'rating', 'image_url', 'scraped_at', 'llm_summary', 'llm_highlights']
#
# Data types:
# title             object
# price             object
# description       object
# url               object
# rating            object
# image_url         object
# scraped_at        object
# llm_summary       object
# llm_highlights    object
# dtype: object
#                                                 title     price         rating
# 0   Sponsored HP - 15.6" Touch-Screen Laptop - Int...   $529.99           None
# 1   Sponsored ASUS ROG Strix G15 15.6” Gaming Lapt...  $1179.99           None
# 2   Sponsored Acer Aspire Go 15.6" Laptop - Silver...   $399.99    (7 Reviews)
# 3   Sponsored Dell - Inspiron 15.6" 120Hz FHD 1920...   $519.99           None
# 4   Microsoft Surface Laptop 13" Copilot+ PC Lapto...  $1499.99    (0 Reviews)
# 5   Microsoft Surface Laptop 13" Copilot+ PC Lapto...  $1499.99    (0 Reviews)
# 6   Microsoft Surface Laptop 13" Copilot+ PC Lapto...  $1499.99    (0 Reviews)
# 7   Lenovo IdeaPad 1i 14" Laptop - Abyss Blue (Int...   $199.99    (4 Reviews)
# 8   Sponsored ASUS Zenbook DUO 14" OLED Touchscree...  $1499.99   (54 Reviews)
# 9   Sponsored ASUS Vivobook 14 Flip 14" Touchscree...   $699.95           None
# 10  Sponsored ASUS Vivobook 16 16" Laptop - Indie ...   $649.99    (6 Reviews)
# 11  Dell Inspiron 15 15.6" Touchscreen Laptop (Int...  $1099.99    (2 Reviews)
# 12  HP Premium Stream 14" HD BrightView Laptop, In...      $399  (634 Reviews)
# 13  Acer Aspire Go 15.6" Laptop - Silver (Intel N1...   $399.99    (7 Reviews)
# 14  ASUS Vivobook 16 16" Laptop - Indie Black (Int...   $649.99    (6 Reviews)

# %%
products[-1]['llm_summary']
# Out:
# "The ASUS Vivobook 16 laptop is designed to handle everyday tasks with ease, thanks to its Intel Core i5-13420H processor, 16GB of RAM, and 512GB solid-state drive (SSD). This means you can expect smooth performance when browsing the web, working on documents, and streaming videos. The laptop's 16-inch display provides a comfortable viewing experience, and with Windows 11, you'll have access to the latest features and security updates. Overall, this laptop is suitable for students, professionals, and anyone looking for a reliable device for general use."

# %%
def examine_product(index):
    """Examine a specific product in detail"""
    if index < len(products):
        product = products[index]
        print(f"=== PRODUCT {index + 1} ===")
        print(f"Title: {product['title']}")
        print(f"Price: {product['price']}")
        print(f"Rating: {product['rating']}")
        print(f"URL: {product['url']}")
        print(f"\nLLM Summary:")
        print(f"{product['llm_summary']}")
        print(f"\nLLM Highlights:")
        for i, highlight in enumerate(product['llm_highlights'], 1):
            print(f"  {i}. {highlight}")
        print("="*60)
    else:
        print(f"Product {index + 1} not found")

for i in range(min(10, len(products))):
    examine_product(i)
# Out:
# === PRODUCT 1 ===
# Title: Sponsored HP - 15.6" Touch-Screen Laptop - Intel Core 6-Core i3 -1215u Up to 4.4GHz - 16GB Memory - 256GB SSD - Natural Silver, Intel UHD Graphics, Windows 11 Home, HDMI 1,4b, WIFI 5 Top Deal $529.99
# Price: $529.99
# Rating: None
# URL: https://www.bestbuy.ca//b.us5.us.criteo.com/rm?dest=https%3A%2F%2Fwww.bestbuy.ca%2Fen-ca%2Fproduct%2Fhp-15-6-touch-screen-laptop-intel-core-6-core-i3-1215u-up-to-4-4ghz-16gb-memory-256gb-ssd-natural-silver-intel-uhd-graphics-windows-11-home-hdmi-1-4b-wifi-5%2F17667138%3Fsource%3Dcategory%26adSlot%3D1%26slotPos%3D1&sig=1-qR7JOOqzlg3yWwVr16W4vrNJvy7X4PdwOSXCHUk29dU&rm_e=AtSrHgleyx7EJ5J0YRgdbDTrYltxRroRJp0XDMjUn86LG0yvCO3IfcnEnrZtBi-1O3j6u5rhkFWrJk3dSpBvFycW_r2We1Ila0jwqaf9U4Y5Xaed7iet-Cn-SxB2T2SdqK9v2CLU0HUbXyOo_DQQCEXlM3cIscSc-WqyQTdmTVuZTNFbU9k5Uut6HMHPqIZx9pKQtqSBEu9pPrNDQ2m8KQNBUi90dHJUhErA9UbvNJ6WJmCZkMjM-1PKtBeIjywVJojDwHwzO4mrIwZQqiljvC-HHuz2Ci8gBgwutJkRyJF_whzyr1LB2n1vHafVRbo5J3pL16efsz5YTZS3VRul8umc5LYS1Yx1AkJRkxXQnvd18CfrfXXvpQUIXGlo6G9p&ev=4
#
# LLM Summary:
# Experience the perfect blend of power and portability with the HP 15.6" Touch-Screen Laptop, designed to elevate your productivity and entertainment on-the-go. With its sleek Natural Silver design and cutting-edge Intel Core i3 processor, this laptop is the ultimate tool for those who demand perform
#
# LLM Highlights:
#   1. Unleash Your Creativity with Lightning-Fast Performance
#   2. Enjoy Seamless Multitasking with Ample Memory and Storage
#   3. Discover Stunning Visuals with Intel UHD Graphics and Touch-Screen Display
#   4. Upgrade Your Mobile Lifestyle with Effortless Connectivity and Portability
# ============================================================
# === PRODUCT 2 ===
# Title: Sponsored Lenovo IdeaPad Slim 5i Laptop, 16" IPS 60Hz, Intel Core 5 120U, 16GB, 512GB SSD (132 Reviews) Top Deal $779 $779.00 SAVE $381 Available online only
# Price: $779
# Rating: (132 Reviews)
# URL: https://www.bestbuy.ca//b.us5.us.criteo.com/rm?dest=https%3A%2F%2Fwww.bestbuy.ca%2Fen-ca%2Fproduct%2Flenovo-ideapad-slim-5i-laptop-16-ips-60hz-intel-core-5-120u-16gb-512gb-ssd%2F17756072%3Fsource%3Dcategory%26adSlot%3D2%26slotPos%3D2&sig=1-y8WrXbRTLP-00OnG_XMiq6DM0Uvon5SlDPkdQrZ8g98&rm_e=Bo6Sp5k8TVcMQufz7akVE0IRl9ffCnIrc613QZBpphIyhFyKpNx54KqYfoV4uKLOh_Jcqoo2JgJs3DfEw9ttx8WjMnciKqGAFqaeCXdeivdr27sAHQ4bNmunkhpJErwO-9cyVpc9S9turi8srFRfr7kzFnBztrHau6fc8omTRLWGfnZlxPyPbqlfAPXMrM5wCvtDOKMzUXwrbi3C-UDmnBQf2cdbs475_33v94c6G3BVM_H6HBnILS7rpcU-UPAdAxdN39CNnVL1TjIark9wb_clzP4fHiz6WezBxBzvkbAhJsHSSyTNuJlUZ9u8XTaD3LyQWK0oSTzeObj0grhFXi8otb0efyzFpfcXhH7rhOpwN_jqHP10lBBzlPHKgFoS&ev=4
#
# LLM Summary:
# Experience unparalleled productivity and entertainment with the Lenovo IdeaPad Slim 5i Laptop, expertly crafted to deliver seamless performance, stunning visuals, and effortless portability. Upgrade your workflow and unlock new possibilities with this powerful, sleek, and feature-rich device. Elevat
#
# LLM Highlights:
#   1. Unleash Your Creativity with Lightning-Fast Performance
#   2. Enjoy Immersive Entertainment with Vivid 16" IPS Display
#   3. Work Smarter with Ample 16GB RAM and 512GB SSD Storage
#   4. Unlock Endless Possibilities with $381 in Savings, Exclusively Online
# ============================================================
# === PRODUCT 3 ===
# Title: Sponsored ASUS ROG Strix G15 15.6” Gaming Laptop FHD 144Hz, GeForce RTX 3050, AMD Ryzen™ 7 6800HS, 16GB DDR5, 512GB PCIe SSD, Wi-Fi 6E, Windows 11 Home, Eclipse Grey $1179.99 $1,179.99 SAVE $620 Avail
# Price: $1179.99
# Rating: None
# URL: https://www.bestbuy.ca//b.us5.us.criteo.com/rm?dest=https%3A%2F%2Fwww.bestbuy.ca%2Fen-ca%2Fproduct%2Fasus-rog-strix-g15-15-6-gaming-laptop-fhd-144hz-geforce-rtx-3050-amd-ryzen-7-6800hs-16gb-ddr5-512gb-pcie-ssd-wi-fi-6e-windows-11-home-eclipse-grey%2F19273730%3Fsource%3Dcategory%26adSlot%3D3%26slotPos%3D3&sig=1-QQU9dS_Y4-UlXC8iVEUIdXSRnK0W89j3FWevDyztOMA&rm_e=zPPTD31lyuPsjgyGY_CHRUxruVDEkzXK34oHwmy5XxH1iKsxYFyqRBW0PKVfwk2vNa6JgFINmqPg37WPLKxwzgB_VKcBAsIgWedBbinajlD0v83Z8RnjZWb68YuKOs7gWgwcDGaFgYD973EWdSnmQ1GI5FMJ5MbbIlkO93HNy3p19lsmavlqB7DSNTumW2NGIqXhx2LyJTPALtZPWrLdsvbI6nqXQCvIpiHeMxwe5COM3S9VPyCygMA5zzH1ADJkMP_LmDR0lG827QjFr24r-p5wio1yQCjOfQcsMuXkGHFtZdbLfZkEPLvliWlEvykYJ--0ya3ckVEK9-11KccaAq9Q2z0RRVE_MwUGM5h_V5GNnj1bW-LGLDedqW75D_F_&ev=4
#
# LLM Summary:
# The ASUS ROG Strix G15 gaming laptop is designed to deliver a seamless gaming experience with its powerful AMD Ryzen 7 6800HS processor, NVIDIA GeForce RTX 3050 graphics card, and 16GB of DDR5 memory. The 15.6" FHD display features a 144Hz refresh rate, providing smooth visuals for fast-paced games.
#
# LLM Highlights:
#   1. paced games. With a 512GB PCIe SSD, you can expect quick loading times and responsive performance. The laptop also supports Wi
#   2. Fi 6E for fast and reliable internet connectivity. For everyday use, this means you can enjoy smooth gaming, efficient multitasking, and rapid file transfers. The laptop's Eclipse Grey design and Windows 11 Home operating system add to its overall appeal.
#   3. The combination of the Ryzen 7 6800HS processor and GeForce RTX 3050 graphics card enables smooth performance in demanding games and applications |
#   4. The laptop's Wi
# ============================================================
# === PRODUCT 4 ===
# Title: Sponsored Acer Aspire Go 15.6" Laptop - Silver (Intel N100/8GB RAM/512GB SSD/Windows 11) (7 Reviews) Top Deal $399.99 $399.99 SAVE $150 Plus $1.35 EHF Available to ship Available at nearby stores
# Price: $399.99
# Rating: (7 Reviews)
# URL: https://www.bestbuy.ca//b.us5.us.criteo.com/rm?dest=https%3A%2F%2Fwww.bestbuy.ca%2Fen-ca%2Fproduct%2Facer-aspire-go-15-6-laptop-silver-intel-n100-8gb-ram-512gb-ssd-windows-11%2F18486669%3Fsource%3Dcategory%26adSlot%3D4%26slotPos%3D4&sig=1-9PgU7PgWFOsu5gDrJQIzVvFGh2ApXHXAOOJeBxpIklg&rm_e=ywivOWrESKPcSiDEKMdLgztpQZPI4dnEHlnW6vt5MfHz9O47wUiu-DiVp_M_hq_wlh-g7eORpiFjm4Sn0vfp7YLIYoo5Wwv7NvXVQDPJ4NRVFq3aylMJE6g-pJCGzHk3Vt48GFoElgNQiLqkkLOYQ9kLlsYGFJrrZbfgAPKJY12nLaI314l_2ofbsx2bnuS5_EoxcAV5sJUk_76TsrbiXU1pxHt7Amwgx9ALnAjD2Ahot5XeXizFopDKherJkj5L52dE6UF59cR7c3Fng728C5s63E4xlz0j9usWdHk5wOx2SkLKD8xHV6rGL8D0WaeRXexxMHW15x0UB_h7qhYgEuPlrcYjNYPQO2jjFbWFW0U&ev=4
#
# LLM Summary:
# Experience the perfect blend of performance and style with the Acer Aspire Go 15.6" Laptop, now available at an unbeatable price of $399.99, a staggering $150 off the regular price. This sleek and powerful device is designed to elevate your productivity and entertainment experience, making it an abs
#
# LLM Highlights:
#   1. Unleash Your Productivity
#   2. Effortless Entertainment
#   3. Storage and Speed at Your Fingertips
#   4. Unbeatable Value for a Premium Laptop Experience
# ============================================================
# === PRODUCT 5 ===
# Title: Microsoft Surface Laptop 13" Copilot+ PC Laptop - Violet (Snapdragon X Plus/16GB RAM/512GB UFS) - EN (0 Reviews) Latest and Greatest $1499.99 $1,499.99 Available to ship Sold out in nearby stores
# Price: $1499.99
# Rating: (0 Reviews)
# URL: https://www.bestbuy.ca/en-ca/product/microsoft-surface-laptop-13-copilot-pc-laptop-violet-snapdragon-x-plus-16gb-ram-512gb-ufs-en/19265465
#
# LLM Summary:
# The Microsoft Surface Laptop 13" Copilot+ PC Laptop - Violet is a high-end, ultra-portable laptop that competes with other premium devices in its category, such as the Apple MacBook Air and the Dell XPS 13. With its sleek design, powerful Qualcomm Snapdragon X Plus processor, and generous 16GB of RA
#
# LLM Highlights:
#   1. Violet is a high
#   2. end, ultra
#   3. portable laptop that competes with other premium devices in its category, such as the Apple MacBook Air and the Dell XPS 13. With its sleek design, powerful Qualcomm Snapdragon X Plus processor, and generous 16GB of RAM, this laptop is well
#   4. suited for demanding tasks and everyday use. However, its price point of $1499.99 may be a barrier for some consumers, especially considering the availability of similar devices with comparable specs at lower price points.
# ============================================================
# === PRODUCT 6 ===
# Title: Microsoft Surface Laptop 13" Copilot+ PC Laptop - Platinum (Snapdragon X Plus/16GB RAM/512GB UFS) - EN (0 Reviews) Latest and Greatest $1499.99 $1,499.99 Available to ship Available at nearby stores
# Price: $1499.99
# Rating: (0 Reviews)
# URL: https://www.bestbuy.ca/en-ca/product/microsoft-surface-laptop-13-copilot-pc-laptop-platinum-snapdragon-x-plus-16gb-ram-512gb-ufs-en/19265466
#
# LLM Summary:
# Get ready to level up your productivity with the Microsoft Surface Laptop 13" Copilot+ PC Laptop - the latest and greatest in tech! This sleek platinum laptop is packed with powerful features like a Snapdragon X Plus processor and 16GB of RAM, making it perfect for work, play, and everything in betw
#
# LLM Highlights:
#   1. the latest and greatest in tech! This sleek platinum laptop is packed with powerful features like a Snapdragon X Plus processor and 16GB of RAM, making it perfect for work, play, and everything in between. Whether you're a student, creator, or entrepreneur, this laptop is about to become your new BFF!
#   2.
#   3. Future
#   4. Proof Performance
# ============================================================
# === PRODUCT 7 ===
# Title: Microsoft Surface Laptop 13" Copilot+ PC Laptop - Ocean (Snapdragon X Plus/16GB RAM/512GB UFS) - EN (0 Reviews) Latest and Greatest $1499.99 $1,499.99 Available to ship Available at nearby stores
# Price: $1499.99
# Rating: (0 Reviews)
# URL: https://www.bestbuy.ca/en-ca/product/microsoft-surface-laptop-13-copilot-pc-laptop-ocean-snapdragon-x-plus-16gb-ram-512gb-ufs-en/19265464
#
# LLM Summary:
# **SUMMARY:** The Microsoft Surface Laptop 13" Copilot+ PC Laptop is a high-end device suitable for individuals seeking a powerful, portable, and sleek laptop for everyday use, content creation, and productivity. This laptop is perfect for those who value premium design, advanced performance, and sea
#
# LLM Highlights:
#   1. SUMMARY:
#   2. The Microsoft Surface Laptop 13" Copilot+ PC Laptop is a high
#   3. end device suitable for individuals seeking a powerful, portable, and sleek laptop for everyday use, content creation, and productivity. This laptop is perfect for those who value premium design, advanced performance, and seamless integration with Microsoft ecosystem. If you're looking for a laptop that can handle demanding tasks, provide an excellent user experience, and boast a stunning display, the Microsoft Surface Laptop 13" Copilot+ is worth considering.
#   4. HIGHLIGHTS:
# ============================================================
# === PRODUCT 8 ===
# Title: Sponsored Lenovo IdeaPad Slim 5i Laptop, 16" IPS 60Hz, Intel Core 5 120U, 16GB, 512GB SSD (132 Reviews) Top Deal $779 $779.00 SAVE $381 Available online only
# Price: $779
# Rating: (132 Reviews)
# URL: https://www.bestbuy.ca//b.us5.us.criteo.com/rm?dest=https%3A%2F%2Fwww.bestbuy.ca%2Fen-ca%2Fproduct%2Flenovo-ideapad-slim-5i-laptop-16-ips-60hz-intel-core-5-120u-16gb-512gb-ssd%2F17756072%3Fsource%3Dcategory%26adSlot%3D2%26slotPos%3D2&sig=1-y8WrXbRTLP-00OnG_XMiq6DM0Uvon5SlDPkdQrZ8g98&rm_e=vAsmUp2Uj3xetuNLaPJfKocAkEjdz3wMCGIEg4glL6-9wN6nLI9_w9YC8LB4WWtRmON5pB3XTz_4cP1tZORrHtHFv5zbml1bP3FsFcq6-OdDCs91zyouTu7NZ_rZM_T4EL4G8Mr1DfrJBxxmiutpFodlZ7sfC3fSrF-qpVl3rBzBlfDktfje5FzPCf5UZg4UVHh7nzKupcvie82aBBp9pLEia01Ts7z0aaVMlAn6x5oodI9ahKwFYnCo1qsh9gOUYXp4VI_ZWbxew-Ksy_HSkuG0GCkaxtYEaymzgQdAjRiPRecJZdekMwVyU2QtRtqOOsikxKtYFBwWRPQ_ItGy7nNW7wvseNEkJtdaeXnV3_erx_BE9ELQtxhDSX3P3-8S&ev=4
#
# LLM Summary:
# Elevate your productivity and creativity with the Lenovo IdeaPad Slim 5i Laptop, expertly designed to deliver seamless performance, stunning visuals, and unparalleled portability. Experience the perfect blend of power and style, tailored to meet the demands of your busy lifestyle. With an unbeatable
#
# LLM Highlights:
#   1. Unleash Your Potential With Lightning-Fast Performance
#   2. Enjoy Stunning Visuals On The Go With Vibrant 16" IPS Display
#   3. Experience Effortless Multitasking With 16GB Of RAM And 512GB SSD
#   4. Upgrade Your Work-Life Balance With A Sleek, Portable Design That Keeps Up With Your Active Lifestyle
# ============================================================
# === PRODUCT 9 ===
# Title: Sponsored ASUS ROG Strix G15 15.6” Gaming Laptop FHD 144Hz, GeForce RTX 3050, AMD Ryzen™ 7 6800HS, 16GB DDR5, 512GB PCIe SSD, Wi-Fi 6E, Windows 11 Home, Eclipse Grey $1179.99 $1,179.99 SAVE $620 Avail
# Price: $1179.99
# Rating: None
# URL: https://www.bestbuy.ca//b.us5.us.criteo.com/rm?dest=https%3A%2F%2Fwww.bestbuy.ca%2Fen-ca%2Fproduct%2Fasus-rog-strix-g15-15-6-gaming-laptop-fhd-144hz-geforce-rtx-3050-amd-ryzen-7-6800hs-16gb-ddr5-512gb-pcie-ssd-wi-fi-6e-windows-11-home-eclipse-grey%2F19273730%3Fsource%3Dcategory%26adSlot%3D3%26slotPos%3D3&sig=1-QQU9dS_Y4-UlXC8iVEUIdXSRnK0W89j3FWevDyztOMA&rm_e=Y_lCZAY0uH95OvDQTMTShjn52KlvD1VgjyqEtQ2HiFpdkIt7mGvY_ix9YVFcIiyu0KTemjZmWppUAaaTrEzjPNuE2BcPwoZ3cSID1JvhqGUGX__sR8-2xQZ-sNa-Jq-TpWNPHoqmFfRQPTDWQgB87p0QtoIrf0ynScwu6W9zsLB-O0qvgzXVwW-FGEX8Q1ZTQ4RvNWUGRhriSgromnYVsyQ3qUT_RpJKJIYpH9FftGZN0tY9Auz5QcqKAZ_av41qbmAEdSUzpODv71dc0cPtvogh1G8WL4rjIrfBMf_YqdcpG7a00krXM2dsWSdrWu_FLcXd6OP4VR5-121TwBqXfCpVM4XoFRCgkqYIyPTKZVNJgR088_2cjuxehb_1X476&ev=4
#
# LLM Summary:
# The ASUS ROG Strix G15 gaming laptop is designed to deliver a seamless gaming experience, thanks to its powerful AMD Ryzen 7 6800HS processor, NVIDIA GeForce RTX 3050 graphics card, and 16GB of DDR5 memory. The 15.6" FHD display features a 144Hz refresh rate, providing smooth visuals and quick respo
#
# LLM Highlights:
#   1. Fi 6E for reliable and speedy internet connectivity. Overall, this laptop is well
#   2. suited for gaming, content creation, and everyday use, offering a great balance of performance, features, and portability.
#   3. The combination of the AMD Ryzen 7 6800HS processor and NVIDIA GeForce RTX 3050 graphics card provides a significant boost to gaming performance, allowing for smooth gameplay and high frame rates in popular titles.
#   4. The laptop's Wi
# ============================================================
# === PRODUCT 10 ===
# Title: Sponsored Acer Aspire Go 15.6" Laptop - Silver (Intel N100/8GB RAM/512GB SSD/Windows 11) (7 Reviews) Top Deal $399.99 $399.99 SAVE $150 Plus $1.35 EHF Available to ship Available at nearby stores
# Price: $399.99
# Rating: (7 Reviews)
# URL: https://www.bestbuy.ca//b.us5.us.criteo.com/rm?dest=https%3A%2F%2Fwww.bestbuy.ca%2Fen-ca%2Fproduct%2Facer-aspire-go-15-6-laptop-silver-intel-n100-8gb-ram-512gb-ssd-windows-11%2F18486669%3Fsource%3Dcategory%26adSlot%3D4%26slotPos%3D4&sig=1-9PgU7PgWFOsu5gDrJQIzVvFGh2ApXHXAOOJeBxpIklg&rm_e=Ze4NYSc9L-ZXwSZuV9oa4WKw31gypBlB9_NnV6yO6XIHK_PVhO3qw-sT2XOlPZuAmc4GZOdQc7jfFY_WHm2TAtQypBY3Ms9nv4GysxUDpUweM7PS2w2N8xJTRDAe6BLu5Tsl1SfPiA6LKGibSVIYyoBww35fwgDCaA_JLX_xZKhE-JsRPkbGOASlEB6kiDaB2awyOccZ9IXkyBC8nMdKG3UMb9E_zC3Mdwn7QxmtVjR3QW1shDXsTLpcDJbZ8KKmu3Zzanyi0Rv9YoeWb7Ve94kCBi0FEZwStkzA3UB_8K64DNyyICfdVLZ2CYg3cSnzndbQa_DLD_HYbAE8e1qEPvvqqpFXUst-kNkkckMj2No&ev=4
#
# LLM Summary:
# Unlock limitless possibilities with the Acer Aspire Go 15.6" Laptop, where sleek design meets unparalleled performance, empowering you to create, connect, and conquer your goals in style. Experience the perfect blend of power, portability, and affordability, making it the ultimate companion for work
#
# LLM Highlights:
#   1. Unleash Your Productivity
#   2. Effortless Multitasking
#   3. Stunning Visuals & Immersive Experience
#   4. Unbeatable Value That Fits Your Lifestyle
# ============================================================

# %%
start_scraping(max_products= 10)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/Documents/GitHub/ecommerce-llm-pipeline/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/Documents/GitHub/ecommerce-llm-pipeline/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/Documents/GitHub/ecommerce-llm-pipeline/venv/lib/python3.11/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.11/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1394 try:
# -> 1395     response.begin()
#    1396 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.11/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.11/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.11/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     717 try:
# --> 718     return self._sock.recv_into(b)
#     719 except timeout:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/Documents/GitHub/ecommerce-llm-pipeline/venv/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/Documents/GitHub/ecommerce-llm-pipeline/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/Documents/GitHub/ecommerce-llm-pipeline/venv/lib/python3.11/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~/Documents/GitHub/ecommerce-llm-pipeline/venv/lib/python3.11/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~/Documents/GitHub/ecommerce-llm-pipeline/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/Documents/GitHub/ecommerce-llm-pipeline/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/Documents/GitHub/ecommerce-llm-pipeline/venv/lib/python3.11/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.11/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1394 try:
# -> 1395     response.begin()
#    1396 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.11/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.11/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.11/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     717 try:
# --> 718     return self._sock.recv_into(b)
#     719 except timeout:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 start_scraping(max_products= 10)
#
# Cell In[11], line 19, in start_scraping(max_products)
#      17 def start_scraping(max_products=10):
#      18     """Start scraping new products"""
# ---> 19     response = requests.post(f"{BASE_URL}/refresh?max_products={max_products}")
#      20     return response.json()
#
# File ~/Documents/GitHub/ecommerce-llm-pipeline/venv/lib/python3.11/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/Documents/GitHub/ecommerce-llm-pipeline/venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Documents/GitHub/ecommerce-llm-pipeline/venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/GitHub/ecommerce-llm-pipeline/venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/GitHub/ecommerce-llm-pipeline/venv/lib/python3.11/site-packages/requests/adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)    678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))

# %%
check_health()
# Out:
# {'status': 'healthy',
#  'cached_products': 24,
#  'scraping_active': False,
#  'last_scraped': '2025-05-31T17:25:25.882339',
#  'storage_file': 'products_database.json',
#  'file_exists': True,
#  'file_size_kb': 45.14}
